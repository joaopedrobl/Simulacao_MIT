# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # visualization
from sklearn.neural_network import MLPClassifier # neural network
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
d_1b = pd.read_csv(r"C:\Repositorios\Simulacao_MIT\Classificador\MLP\dataset\csv_files\Todos\Falha_1b_componentes.csv", usecols=["Failure", "Type", "L_freq", "R_freq"])
d_2b = pd.read_csv(r"C:\Repositorios\Simulacao_MIT\Classificador\MLP\dataset\csv_files\Todos\Falha_2b_componentes.csv", usecols=["Failure", "Type", "L_freq", "R_freq"])
d_3b = pd.read_csv(r"C:\Repositorios\Simulacao_MIT\Classificador\MLP\dataset\csv_files\Todos\Falha_3b_componentes.csv", usecols=["Failure", "Type", "L_freq", "R_freq"])
d_3ba= pd.read_csv(r"C:\Repositorios\Simulacao_MIT\Classificador\MLP\dataset\csv_files\Todos\Falha_3ba_componentes.csv", usecols=["Failure", "Type", "L_freq", "R_freq"])
d_n= pd.read_csv(r"C:\Repositorios\Simulacao_MIT\Classificador\MLP\dataset\csv_files\Todos\Normal_componentes.csv", usecols=["Failure", "Type", "L_freq", "R_freq"])

# %%
d_n
# Out:
#     Failure  Type    L_freq    R_freq
# 0       0.0   1.0  0.000000  0.000000
# 1       0.0   1.0  0.000000  0.000000
# 2       0.0   1.0  0.000000  0.000000
# 3       0.0   2.0  0.000000  0.000000
# 4       0.0   2.0  0.000000  0.000000
# ..      ...   ...       ...       ...
# 58      0.0  20.0  0.603626  0.699317
# 59      0.0  20.0  0.607677  0.576581
# 60      0.0  21.0  1.129452  1.125842
# 61      0.0  21.0  1.072265  1.061493
# 62      0.0  21.0  1.048681  0.000000
#
# [63 rows x 4 columns]

# %%
d_n.L_freq
# Out:
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000000
#         ...
# 58    0.603626
# 59    0.607677
# 60    1.129452
# 61    1.072265
# 62    1.048681
# Name: L_freq, Length: 63, dtype: float64

# %%
plt.plot(d_n.index, d_n.L_freq, d_n.index, d_3ba.L_freq, d_n.index, d_1b.L_freq, d_n.index, d_2b.L_freq)
